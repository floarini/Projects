# %% [markdown]
# # This repo is to show the data viz using Python's libraries to make scatter plot and regression plot.

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import PercentFormatter
sns.set()

# %% [markdown]
# ###  Scatter Plot of Student Scores

# %% [markdown]
# #### Plot the GPA and SAT student scores using a scatter plot.

# %%
df_student_scores = pd.read_csv("student_scores_data.csv")

# %%
df_student_scores
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
# The scatter plot displaying the SAT scores and GPA for the students, shows a relationship between the two variables. 
# It seems the higher the SAT score, the more likely it is for students to obtain a higher GPA.
# Note that the plot is automatically adjusted, so the x and y-axis do not start from 0. Instead, they reflect the variables domain.
plt.figure(figsize = (12, 8))
scatter = plt.scatter(df_student_scores['SAT'],
                      df_student_scores['GPA'], 
                      color = "midnightblue") 
plt.title("GPA and SAT Student Scores", 
          fontsize = 14, 
          weight = "bold")
plt.xlabel("SAT", weight = "bold")
plt.ylabel("GPA", weight = "bold")
plt.show()

# %% [markdown]
# ### Regression Plot of Auto Insurance in Sweden

# %%
df_auto_insurance = pd.read_csv("regression_auto_insurance_sweden.csv")

# %%
df_auto_insurance
# Out:
#     Claims  Payment
# 0      108    392.5
# 1       19     46.2
# 2       13     15.7
# 3      124    422.2
# 4       40    119.4
# ..     ...      ...
# 58       9     87.4
# 59      31    209.8
# 60      14     95.5
# 61      53    244.6
# 62      26    187.5
#
# [63 rows x 2 columns]

# %%
# Regresssion plot of the car insurance data using a reg plot.
# What I observed is that there seems to be a linear relationship between the two variables. The higher the insurance claim, the higher the payment it has received.
sns.set(rc = {'figure.figsize': (9,6)})
sns.regplot(x = "Claims", 
            y = "Payment", 
            data = df_auto_insurance, 
            scatter_kws = {'color': 'k'}, 
            line_kws = {'color': 'red'})
plt.xlabel("Claims")
plt.ylabel("Payment")
plt.title("Car Insurance Claims and Payment in Sweden", fontsize = 14, weight = "bold")
plt.show()

# %%
# The car insurance data visualized using an sns lm plot
sns.lmplot(x = "Claims", 
           y = "Payment", 
           data = df_auto_insurance,  
           height = 10, 
           scatter_kws = {'color': 'k'}, 
           line_kws = {'color': 'red'})
plt.xlabel("Claims")
plt.ylabel("Payment")
plt.title("Car Insurance Claims and Payment in Sweden", fontsize = 14, weight = "bold")
plt.show()
